# %% [markdown]
# # Data Exploration
#
# Week 1 notebook — load the four FRED series, visualize regime labels, spot any anomalies before modeling.

# %%
from conformal_econ.data.fred import load_all_series
from conformal_econ.data.regime import label_regimes

series = load_all_series()
for sid, df in series.items():
    labeled = label_regimes(df, sid)
    print(sid, labeled['regime'].value_counts().to_dict())
