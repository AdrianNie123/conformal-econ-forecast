# %% [markdown]
# # Results Analysis
#
# Week 3 notebook — load benchmark_results.parquet, reproduce the coverage deviation tables, check the headline finding.

# %%
# TODO (Week 3): Load results/benchmark_results.parquet, slice by regime,
#                confirm conformal coverage is within ±3% of target.
