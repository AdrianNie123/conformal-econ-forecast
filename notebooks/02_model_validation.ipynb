# %% [markdown]
# # Model Validation
#
# Week 2 notebook — fit each model, sanity-check point forecasts and Gaussian intervals before wrapping with MAPIE.

# %%
# TODO (Week 2): Load a series, fit ARIMA/ETS/RF/XGBoost, plot forecasts.
